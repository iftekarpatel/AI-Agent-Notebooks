# %% [markdown]
# # TASK 1. PROJECT OVERVIEW & KEY LEARNING OBJECTIVES

# %% [markdown]
# # TASK 2. SETTING UP YOUR ENVIRONMENT

# %% [markdown]
# Before we can build our first AI agent, we need two things:
#
# 1. The `openai-agents` library installed.
# 2. Your secret OpenAI API key to communicate with the AI models.
#
# > **Security tip 📌** Store keys securely in a `.env` file. Make sure you have a file named `.env` in the same directory as this notebook with your key:
# >
# > ```dotenv
# > OPENAI_API_KEY=sk-YourSecretOpenAIKeyGoesHereXXXXXXXXXXXXX
# > ```
#
# Let's run the cells below to install the necessary packages and load your API key.

# %% [markdown]
# - **You can access the OpenAI API here: https://openai.com/api/**

# %%
# Uninstall openai-agents - if you have it installed
# Note that an SDK stands for "software development kit" which is a toolbox for building software for a specific platform or service.
# !pip uninstall -y openai-agents
# Out:
# WARNING: Skipping openai-agents as it is not installed.

# %%
# Install the specific version of openai-agents
# !pip install --no-cache-dir openai-agents==0.2.2
# Out:
# Collecting openai-agents==0.2.2
#   Downloading openai_agents-0.2.2-py3-none-any.whl.metadata (11 kB)
# Collecting griffe<2,>=1.5.6 (from openai-agents==0.2.2)
#   Downloading griffe-1.15.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting mcp<2,>=1.11.0 (from openai-agents==0.2.2)
#   Downloading mcp-1.26.0-py3-none-any.whl.metadata (89 kB)
# Collecting openai<2,>=1.96.1 (from openai-agents==0.2.2)
#   Downloading openai-1.109.1-py3-none-any.whl.metadata (29 kB)
# Collecting pydantic<3,>=2.10 (from openai-agents==0.2.2)
#   Downloading pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Requirement already satisfied: requests<3,>=2.0 in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from openai-agents==0.2.2) (2.32.5)
# Collecting types-requests<3,>=2.0 (from openai-agents==0.2.2)
#   Downloading types_requests-2.32.4.20260107-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions<5,>=4.12.2 in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from openai-agents==0.2.2) (4.15.0)
# Requirement already satisfied: colorama>=0.4 in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from griffe<2,>=1.5.6->openai-agents==0.2.2) (0.4.6)
# Requirement already satisfied: anyio>=4.5 in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from mcp<2,>=1.11.0->openai-agents==0.2.2) (4.12.1)
# Collecting httpx-sse>=0.4 (from mcp<2,>=1.11.0->openai-agents==0.2.2)
#   Downloading httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: httpx>=0.27.1 in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from mcp<2,>=1.11.0->openai-agents==0.2.2) (0.28.1)
# Requirement already satisfied: jsonschema>=4.20.0 in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from mcp<2,>=1.11.0->openai-agents==0.2.2) (4.26.0)
# Collecting pydantic-settings>=2.5.2 (from mcp<2,>=1.11.0->openai-agents==0.2.2)
#   Downloading pydantic_settings-2.12.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting pyjwt>=2.10.1 (from pyjwt[crypto]>=2.10.1->mcp<2,>=1.11.0->openai-agents==0.2.2)
#   Downloading pyjwt-2.11.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting python-multipart>=0.0.9 (from mcp<2,>=1.11.0->openai-agents==0.2.2)
#   Downloading python_multipart-0.0.22-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: pywin32>=310 in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from mcp<2,>=1.11.0->openai-agents==0.2.2) (311)
# Collecting sse-starlette>=1.6.1 (from mcp<2,>=1.11.0->openai-agents==0.2.2)
#   Downloading sse_starlette-3.2.0-py3-none-any.whl.metadata (12 kB)
# Collecting starlette>=0.27 (from mcp<2,>=1.11.0->openai-agents==0.2.2)
#   Downloading starlette-0.52.1-py3-none-any.whl.metadata (6.3 kB)
# Collecting typing-inspection>=0.4.1 (from mcp<2,>=1.11.0->openai-agents==0.2.2)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting uvicorn>=0.31.1 (from mcp<2,>=1.11.0->openai-agents==0.2.2)
#   Downloading uvicorn-0.40.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting distro<2,>=1.7.0 (from openai<2,>=1.96.1->openai-agents==0.2.2)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting jiter<1,>=0.4.0 (from openai<2,>=1.96.1->openai-agents==0.2.2)
#   Downloading jiter-0.13.0-cp310-cp310-win_amd64.whl.metadata (5.3 kB)
# Collecting sniffio (from openai<2,>=1.96.1->openai-agents==0.2.2)
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting tqdm>4 (from openai<2,>=1.96.1->openai-agents==0.2.2)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from anyio>=4.5->mcp<2,>=1.11.0->openai-agents==0.2.2) (1.3.1)
# Requirement already satisfied: idna>=2.8 in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from anyio>=4.5->mcp<2,>=1.11.0->openai-agents==0.2.2) (3.11)
# Requirement already satisfied: certifi in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from httpx>=0.27.1->mcp<2,>=1.11.0->openai-agents==0.2.2) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from httpx>=0.27.1->mcp<2,>=1.11.0->openai-agents==0.2.2) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from httpcore==1.*->httpx>=0.27.1->mcp<2,>=1.11.0->openai-agents==0.2.2) (0.16.0)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=2.10->openai-agents==0.2.2)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic<3,>=2.10->openai-agents==0.2.2)
#   Downloading pydantic_core-2.41.5-cp310-cp310-win_amd64.whl.metadata (7.4 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from requests<3,>=2.0->openai-agents==0.2.2) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from requests<3,>=2.0->openai-agents==0.2.2) (2.6.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from jsonschema>=4.20.0->mcp<2,>=1.11.0->openai-agents==0.2.2) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from jsonschema>=4.20.0->mcp<2,>=1.11.0->openai-agents==0.2.2) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from jsonschema>=4.20.0->mcp<2,>=1.11.0->openai-agents==0.2.2) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from jsonschema>=4.20.0->mcp<2,>=1.11.0->openai-agents==0.2.2) (0.30.0)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings>=2.5.2->mcp<2,>=1.11.0->openai-agents==0.2.2)
#   Downloading python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Collecting cryptography>=3.4.0 (from pyjwt[crypto]>=2.10.1->mcp<2,>=1.11.0->openai-agents==0.2.2)
#   Downloading cryptography-46.0.5-cp38-abi3-win_amd64.whl.metadata (5.7 kB)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2,>=1.11.0->openai-agents==0.2.2) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2,>=1.11.0->openai-agents==0.2.2) (3.0)
# Collecting click>=7.0 (from uvicorn>=0.31.1->mcp<2,>=1.11.0->openai-agents==0.2.2)
#   Downloading click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Downloading openai_agents-0.2.2-py3-none-any.whl (161 kB)
# Downloading griffe-1.15.0-py3-none-any.whl (150 kB)
# Downloading mcp-1.26.0-py3-none-any.whl (233 kB)
# Downloading openai-1.109.1-py3-none-any.whl (948 kB)
#    ---------------------------------------- 0.0/948.6 kB ? eta -:--:--
#    ---------------------------------------- 948.6/948.6 kB 7.3 MB/s  0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading jiter-0.13.0-cp310-cp310-win_amd64.whl (206 kB)
# Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp310-cp310-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ------------------------------- -------- 1.6/2.0 MB 8.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 8.0 MB/s  0:00:00
# Downloading types_requests-2.32.4.20260107-py3-none-any.whl (20 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Downloading pydantic_settings-2.12.0-py3-none-any.whl (51 kB)
# Downloading pyjwt-2.11.0-py3-none-any.whl (28 kB)
# Downloading cryptography-46.0.5-cp38-abi3-win_amd64.whl (3.5 MB)
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    --------------- ------------------------ 1.3/3.5 MB 8.4 MB/s eta 0:00:01
#    ------------------------------------ --- 3.1/3.5 MB 7.7 MB/s eta 0:00:01
#    ---------------------------------------- 3.5/3.5 MB 7.6 MB/s  0:00:00
# Downloading python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Downloading python_multipart-0.0.22-py3-none-any.whl (24 kB)
# Downloading sse_starlette-3.2.0-py3-none-any.whl (12 kB)
# Downloading starlette-0.52.1-py3-none-any.whl (74 kB)
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading uvicorn-0.40.0-py3-none-any.whl (68 kB)
# Downloading click-8.3.1-py3-none-any.whl (108 kB)
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: typing-inspection, types-requests, tqdm, sniffio, python-multipart, python-dotenv, pyjwt, pydantic-core, jiter, httpx-sse, griffe, distro, click, annotated-types, uvicorn, pydantic, cryptography, starlette, pydantic-settings, sse-starlette, openai, mcp, openai-agents
#
#    --- ------------------------------------  2/23 [tqdm]
#    -------- -------------------------------  5/23 [python-dotenv]
#    ------------ ---------------------------  7/23 [pydantic-core]
#    ----------------- ---------------------- 10/23 [griffe]
#    ----------------- ---------------------- 10/23 [griffe]
#    ------------------- -------------------- 11/23 [distro]
#    -------------------- ------------------- 12/23 [click]
#    ------------------------ --------------- 14/23 [uvicorn]
#    -------------------------- ------------- 15/23 [pydantic]
#    -------------------------- ------------- 15/23 [pydantic]
#    -------------------------- ------------- 15/23 [pydantic]
#    -------------------------- ------------- 15/23 [pydantic]
#    -------------------------- ------------- 15/23 [pydantic]
#    --------------------------- ------------ 16/23 [cryptography]
#    --------------------------- ------------ 16/23 [cryptography]
#    --------------------------- ------------ 16/23 [cryptography]
#    ----------------------------- ---------- 17/23 [starlette]
#    ----------------------------- ---------- 17/23 [starlette]
#    ------------------------------- -------- 18/23 [pydantic-settings]
#    ---------------------------------- ----- 20/23 [openai]
#    ---------------------------------- ----- 20/23 [openai]
#    ---------------------------------- ----- 20/23 [openai]
#    ---------------------------------- ----- 20/23 [openai]
#    ---------------------------------- ----- 20/23 [openai]
#    ---------------------------------- ----- 20/23 [openai]
#    ---------------------------------- ----- 20/23 [openai]
#    ---------------------------------- ----- 20/23 [openai]
#    ---------------------------------- ----- 20/23 [openai]
#    ---------------------------------- ----- 20/23 [openai]
#    ---------------------------------- ----- 20/23 [openai]
#    ---------------------------------- ----- 20/23 [openai]
#    ---------------------------------- ----- 20/23 [openai]
#    ---------------------------------- ----- 20/23 [openai]
#    ---------------------------------- ----- 20/23 [openai]
#    ---------------------------------- ----- 20/23 [openai]
#    ---------------------------------- ----- 20/23 [openai]
#    ---------------------------------- ----- 20/23 [openai]
#    ---------------------------------- ----- 20/23 [openai]
#    ---------------------------------- ----- 20/23 [openai]
#    ---------------------------------- ----- 20/23 [openai]
#    ---------------------------------- ----- 20/23 [openai]
#    ---------------------------------- ----- 20/23 [openai]
#    ---------------------------------- ----- 20/23 [openai]
#    ---------------------------------- ----- 20/23 [openai]
#    ---------------------------------- ----- 20/23 [openai]
#    ---------------------------------- ----- 20/23 [openai]
#    ---------------------------------- ----- 20/23 [openai]
#    ---------------------------------- ----- 20/23 [openai]
#    ---------------------------------- ----- 20/23 [openai]
#    ---------------------------------- ----- 20/23 [openai]
#    ------------------------------------ --- 21/23 [mcp]
#    ------------------------------------ --- 21/23 [mcp]
#    ------------------------------------ --- 21/23 [mcp]
#    ------------------------------------ --- 21/23 [mcp]
#    ------------------------------------ --- 21/23 [mcp]
#    -------------------------------------- - 22/23 [openai-agents]
#    -------------------------------------- - 22/23 [openai-agents]
#    -------------------------------------- - 22/23 [openai-agents]
#    -------------------------------------- - 22/23 [openai-agents]
#    ---------------------------------------- 23/23 [openai-agents]
#
# Successfully installed annotated-types-0.7.0 click-8.3.1 cryptography-46.0.5 distro-1.9.0 griffe-1.15.0 httpx-sse-0.4.3 jiter-0.13.0 mcp-1.26.0 openai-1.109.1 openai-agents-0.2.2 pydantic-2.12.5 pydantic-core-2.41.5 pydantic-settings-2.12.0 pyjwt-2.11.0 python-dotenv-1.2.1 python-multipart-0.0.22 sniffio-1.3.1 sse-starlette-3.2.0 starlette-0.52.1 tqdm-4.67.3 types-requests-2.32.4.20260107 typing-inspection-0.4.2 uvicorn-0.40.0

# %%
# Install required Python packages:
# langchain-openai==0.2.1: a specific version of LangChain’s OpenAI integration library
# LangChain is a framework that makes it easier to build applications powered by large language models 
# It provides tools to connect to AI models, store context, and chain multiple steps together.
# !pip install python-dotenv langchain-openai==0.2.1

# Upgrade the Pydantic library (used for validating and organizing data)  
# This ensures compatibility with the installed packages above  
# !pip install --upgrade pydantic
# Out:
# Requirement already satisfied: python-dotenv in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (1.2.1)
# Collecting langchain-openai==0.2.1
#   Downloading langchain_openai-0.2.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting langchain-core<0.4,>=0.3 (from langchain-openai==0.2.1)
#   Downloading langchain_core-0.3.83-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: openai<2.0.0,>=1.40.0 in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from langchain-openai==0.2.1) (1.109.1)
# Collecting tiktoken<1,>=0.7 (from langchain-openai==0.2.1)
#   Downloading tiktoken-0.12.0-cp310-cp310-win_amd64.whl.metadata (6.9 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<0.4,>=0.3->langchain-openai==0.2.1)
#   Downloading langsmith-0.7.1-py3-none-any.whl.metadata (15 kB)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<0.4,>=0.3->langchain-openai==0.2.1)
#   Using cached tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<0.4,>=0.3->langchain-openai==0.2.1)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from langchain-core<0.4,>=0.3->langchain-openai==0.2.1) (6.0.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from langchain-core<0.4,>=0.3->langchain-openai==0.2.1) (4.15.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from langchain-core<0.4,>=0.3->langchain-openai==0.2.1) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from langchain-core<0.4,>=0.3->langchain-openai==0.2.1) (2.12.5)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<0.4,>=0.3->langchain-openai==0.2.1)
#   Using cached uuid_utils-0.14.0-cp39-abi3-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<0.4,>=0.3->langchain-openai==0.2.1) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<0.4,>=0.3->langchain-openai==0.2.1) (0.28.1)
# Collecting orjson>=3.9.14 (from langsmith<1.0.0,>=0.3.45->langchain-core<0.4,>=0.3->langchain-openai==0.2.1)
#   Downloading orjson-3.11.7-cp310-cp310-win_amd64.whl.metadata (43 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<0.4,>=0.3->langchain-openai==0.2.1)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: requests>=2.0.0 in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<0.4,>=0.3->langchain-openai==0.2.1) (2.32.5)
# Collecting xxhash>=3.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<0.4,>=0.3->langchain-openai==0.2.1)
#   Downloading xxhash-3.6.0-cp310-cp310-win_amd64.whl.metadata (13 kB)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<0.4,>=0.3->langchain-openai==0.2.1)
#   Downloading zstandard-0.25.0-cp310-cp310-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: anyio in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<0.4,>=0.3->langchain-openai==0.2.1) (4.12.1)
# Requirement already satisfied: certifi in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<0.4,>=0.3->langchain-openai==0.2.1) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<0.4,>=0.3->langchain-openai==0.2.1) (1.0.9)
# Requirement already satisfied: idna in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<0.4,>=0.3->langchain-openai==0.2.1) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<0.4,>=0.3->langchain-openai==0.2.1) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from openai<2.0.0,>=1.40.0->langchain-openai==0.2.1) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from openai<2.0.0,>=1.40.0->langchain-openai==0.2.1) (0.13.0)
# Requirement already satisfied: sniffio in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from openai<2.0.0,>=1.40.0->langchain-openai==0.2.1) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from openai<2.0.0,>=1.40.0->langchain-openai==0.2.1) (4.67.3)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<0.4,>=0.3->langchain-openai==0.2.1) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.4,>=0.3->langchain-openai==0.2.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.4,>=0.3->langchain-openai==0.2.1) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<0.4,>=0.3->langchain-openai==0.2.1) (0.4.2)
# Collecting regex>=2022.1.18 (from tiktoken<1,>=0.7->langchain-openai==0.2.1)
#   Using cached regex-2026.1.15-cp310-cp310-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<0.4,>=0.3->langchain-openai==0.2.1) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<0.4,>=0.3->langchain-openai==0.2.1) (2.6.3)
# Requirement already satisfied: colorama in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from tqdm>4->openai<2.0.0,>=1.40.0->langchain-openai==0.2.1) (0.4.6)
# Downloading langchain_openai-0.2.1-py3-none-any.whl (49 kB)
# Downloading langchain_core-0.3.83-py3-none-any.whl (458 kB)
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langsmith-0.7.1-py3-none-any.whl (322 kB)
# Using cached tenacity-9.1.4-py3-none-any.whl (28 kB)
# Downloading tiktoken-0.12.0-cp310-cp310-win_amd64.whl (879 kB)
#    ---------------------------------------- 0.0/879.4 kB ? eta -:--:--
#    ---------------------------------------- 879.4/879.4 kB 6.6 MB/s  0:00:00
# Using cached uuid_utils-0.14.0-cp39-abi3-win_amd64.whl (182 kB)
# Downloading orjson-3.11.7-cp310-cp310-win_amd64.whl (125 kB)
# Using cached regex-2026.1.15-cp310-cp310-win_amd64.whl (277 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading xxhash-3.6.0-cp310-cp310-win_amd64.whl (31 kB)
# Downloading zstandard-0.25.0-cp310-cp310-win_amd64.whl (506 kB)
# Installing collected packages: zstandard, xxhash, uuid-utils, tenacity, regex, orjson, jsonpatch, tiktoken, requests-toolbelt, langsmith, langchain-core, langchain-openai
#
#    ------ ---------------------------------  2/12 [uuid-utils]
#    ------------- --------------------------  4/12 [regex]
#    ---------------- -----------------------  5/12 [orjson]
#    ----------------------- ----------------  7/12 [tiktoken]
#    -------------------------- -------------  8/12 [requests-toolbelt]
#    ------------------------------ ---------  9/12 [langsmith]
#    ------------------------------ ---------  9/12 [langsmith]
#    ------------------------------ ---------  9/12 [langsmith]
#    ------------------------------ ---------  9/12 [langsmith]
#    ------------------------------ ---------  9/12 [langsmith]
#    --------------------------------- ------ 10/12 [langchain-core]
#    --------------------------------- ------ 10/12 [langchain-core]
#    --------------------------------- ------ 10/12 [langchain-core]
#    --------------------------------- ------ 10/12 [langchain-core]
#    --------------------------------- ------ 10/12 [langchain-core]
#    --------------------------------- ------ 10/12 [langchain-core]
#    --------------------------------- ------ 10/12 [langchain-core]
#    --------------------------------- ------ 10/12 [langchain-core]
#    --------------------------------- ------ 10/12 [langchain-core]
#    ------------------------------------ --- 11/12 [langchain-openai]
#    ---------------------------------------- 12/12 [langchain-openai]
#
# Successfully installed jsonpatch-1.33 langchain-core-0.3.83 langchain-openai-0.2.1 langsmith-0.7.1 orjson-3.11.7 regex-2026.1.15 requests-toolbelt-1.0.0 tenacity-9.1.4 tiktoken-0.12.0 uuid-utils-0.14.0 xxhash-3.6.0 zstandard-0.25.0
# Requirement already satisfied: pydantic in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (2.12.5)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from pydantic) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from pydantic) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\edutech\anaconda3\envs\py310\lib\site-packages (from pydantic) (0.4.2)

# %%
# Let's import "os" module, which stands for "Operating System"
# The os module in Python provides a way to interact with the operating system for things like:
# (1) accessing Environment Variables
# (2) Creating, renaming, and deleting files/folders.
import os
from openai import OpenAI
from IPython.display import display, Markdown

# This will be used to load the API key from the .env file
from dotenv import load_dotenv
load_dotenv()

# Get the OpenAI API keys from environment variables
openai_api_key = os.getenv("OPENAI_API_KEY")

# Let's configure the OpenAI Client using our key
openai_client = OpenAI(api_key = openai_api_key)
print("OpenAI client successfully configured.")

# Let's view the first few characters in the key
print(openai_api_key[:5])
# Out:
# OpenAI client successfully configured.
# sk-pr

# %%
# A Function used to Show the given text using Markdown formatting in a Jupyter notebook
def print_markdown(text):
    """Displays text as Markdown in Jupyter."""
    display(Markdown(text))

# %% [markdown]
# # TASK 3. BUILD & RUN YOUR FIRST AI AGENT USING OPENAI AGENT SDK

# %% [markdown]
# It's time to build our first agent! We will use the `Agent` class from the `openai-agents` library.
#
# Creating an agent is like hiring an employee. You need to provide a **job description**. The key parameters are:
#
# * **client** – The OpenAI client we just configured. This is the agent's connection to the AI brain.
# * **name** – A simple name to identify your agent (e.g., "Fact Checker").
# * **instructions** – The most important part. It's the "system prompt" or the detailed job description for the agent. This tells the agent who to be and what to do.
# * **model** – The specific OpenAI model the agent will use (e.g., `gpt-4o-mini` is fast and cost‑effective or use the latest `gpt-5` for enhanced results and longer context).

# %% [markdown]
# ![image.png](attachment:7bcbe378-1e1f-4ea3-9ea8-bc9db814b958.png)

# %%
# Import the OpenAI API client
from openai import OpenAI 

# Import the Agent class to create and manage AI agents
from agents import Agent

# Define the instructions for the fact-checker AI Agent
fact_checker_instructions = """
Context:
You are a fact-checker who verifies the accuracy of statements.

Instructions:
When given a statement, carefully analyze its factual accuracy using your knowledge.

Input:
You will receive a statement that requires fact-checking.

Output:
Respond with:
1. A verdict prefix: either "✅ TRUE:" or "❌ FALSE:"
2. A brief, one-sentence explanation justifying your conclusion
"""

# %%
# Create a new agent called "Fact Checker"
fact_checker_agent = Agent(name = "Fact Checker",   # Name of the agent
                           instructions = fact_checker_instructions, # The rules and behavior for the agent
                           model = "gpt-4.1-mini") # The AI model (LLM) to use

# Print a confirmation message that the agent was created
print(f"Agent '{fact_checker_agent.name}' created successfully!")
# Out:
# Agent 'Fact Checker' created successfully!

# %% [markdown]
# Let's put our `fact_checker_agent` to work! We'll use the `Runner.run()` method to send it a statement to fact-check. The agent will analyze the statement and return its verdict along with a brief explanation.

# %%
# Import the Runner class, which is used to run an agent and get its output
from agents import Runner

# A statement we want the Fact Checker agent to verify
statement = "The Great Wall of China is visible from space with the naked eye."

# Display the statement we're going to check (in markdown format for nicer formatting)
print_markdown(f"Asking the Fact Checker to verify: '{statement}'")

# Run the Fact Checker agent on the input statement
# 'await' is used because running the agent is an asynchronous operation (it might take time)
response = await Runner.run(
    starting_agent = fact_checker_agent,  # The agent we created earlier
    input = statement                 # The statement we want it to fact-check
)

# Display the agent's response
print_markdown("\n🤖 Agent's Response:\n")
print_markdown(response.final_output)    # Shows the final verdict and explanation
# Out:
# Asking the Fact Checker to verify: 'The Great Wall of China is visible from space with the naked eye.'
# 🤖 Agent's Response:
# ❌ FALSE: The Great Wall of China is generally not visible from space with the naked eye due to its narrow width and the difficulty of distinguishing it from the surrounding terrain.

# %% [markdown]
# **PRACTICE OPPORTUNITY:**
# - **Now it's your turn to experiment with OpenAI API Agents SDK; perform the following tasks:**
#    - **Change the text inside the `statement` variable. Try a different fact, like `"The tallest mountain in the world is Mount Everst"` See how the AI agent responds!**
#    - **Try a different AI model, change the model from `model="gpt-4o-mini"` to `model="gpt-5-mini"`**

# %% [markdown]
# ## TASK 4. CHECK IF THE AI AGENT CAN RECALL INFORMATION (NO MEMORY) & CHECK TRACES

# %%
check_recall_statement = "What did we discuss in the last message?"

response = await Runner.run(starting_agent = fact_checker_agent, input = check_recall_statement)
print_markdown("\n🤖 Agent's Response:\n")
print_markdown(response.final_output)
# Out:
# 🤖 Agent's Response:
# ❌ FALSE: You did not provide a statement in your last message that requires fact-checking; you asked a question about our previous discussion instead.

# %% [markdown]
# - **Note: You can monitor what the Agent did through traces, available in the OpenAI platform when you log in to your account.**
# - **Link: https://platform.openai.com/logs/**

# %% [markdown]
# ![image.png](attachment:31ccc9a0-1cda-4c7f-b9d0-00de3922cf56.png)

# %% [markdown]
# **OpenAI Tokenizer: https://platform.openai.com/tokenizer**

# %% [markdown]
# **PRACTICE OPPORTUNITY:**
# - **Create a new AI agent named `Tweet Bot` that writes a creative, engaging tweet (≤280 characters) about a given topic using OpenAI Agents SDK. The tweet should include at least one emoji and a hashtag.**
#     - **1. Set Up Instructions: Define `Tweet Bot`’s purpose and personality, and configure it to use the latest `gpt-5-mini` model**.
#     - **2. Choose a Topic: For example use "The future of renewable energy"**.
#     - **3. Run the Agent: Use `Runner.run()` to execute the agent and print the generated tweet. Use traces to track the Agent behaviour and list the number of input and output tokens used.**

# %% [markdown]
# # PRACTICE OPPORTUNITY SOLUTIONS

# %% [markdown]
# **PRACTICE OPPORTUNITY SOLUTION:**
# - **Now it's your turn to experiment with OpenAI API Agents SDK; perform the following tasks:**
#    - **Change the text inside the `statement` variable. Try a different fact, like `"The tallest mountain in the world is Mount Everst"` See how the AI agent responds!**
#    - **Try a different AI model, change the model from `model="gpt-4o-mini"` to `model="gpt-5-mini"`**

# %% [markdown]
# **OpenAI Models: https://platform.openai.com/docs/models**

# %%
# Create a new agent called "Fact Checker"
fact_checker_agent = Agent(name = "Fact Checker",   # Name of the agent
                           instructions = fact_checker_instructions, # The rules and behavior for the agent
                           model = "gpt-5-mini") # The AI model (LLM) to use

# Print a confirmation message that the agent was created
print(f"Agent '{fact_checker_agent.name}' created successfully!")
# Out:
# Agent 'Fact Checker' created successfully!

# %%
# Import the Runner class, which is used to run an agent and get its output
from agents import Runner

# A statement we want the Fact Checker agent to verify
statement = "The tallest mountain in the world is Mount Everst"

# Display the statement we're going to check (in markdown format for nicer formatting)
print_markdown(f"Asking the Fact Checker to verify: '{statement}'")

# Run the Fact Checker agent on the input statement
# 'await' is used because running the agent is an asynchronous operation (it might take time)
response = await Runner.run(
    starting_agent = fact_checker_agent,  # The agent we created earlier
    input = statement                 # The statement we want it to fact-check
)

# Display the agent's response
print_markdown("\n🤖 Agent's Response:\n")
print_markdown(response.final_output)    # Shows the final verdict and explanation
# Out:
# Asking the Fact Checker to verify: 'The tallest mountain in the world is Mount Everst'
# 🤖 Agent's Response:
# ✅ TRUE: Mount Everest (spelled "Everest") is the highest mountain above sea level at 8,848.86 m (29,031.7 ft), though Mauna Kea is taller if measured from base to summit.

# %% [markdown]
# **PRACTICE OPPORTUNITY SOLUTION:**
# - **Create a new AI agent named `Tweet Bot` that writes a creative, engaging tweet (≤280 characters) about a given topic using OpenAI Agents SDK. The tweet should include at least one emoji and a hashtag.**
#     - **1. Set Up Instructions: Define `Tweet Bot`’s purpose and personality, and configure it to use the latest `gpt-5-mini` model**.
#     - **2. Choose a Topic: For example use "The future of renewable energy"**.
#     - **3. Run the Agent: Use `Runner.run()` to execute the agent and print the generated tweet. Use traces to track the Agent behaviour and list the number of input and output tokens used.**
